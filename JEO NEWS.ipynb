# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
url = "https://urdu.geo.tv/"

# %%
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
}

# %%
r = requests.get(url,{'headers':headers})

# %%
soup = bs4.BeautifulSoup(r.text,'html.parser')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="806127442825208" property="fb:app_id">
# <meta content="111331428916358" property="fb:pages">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu</title>
# <meta content="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu" name="TITLE"/>
# <meta content="Urdu News - Visit Geo News Urdu online to read latest urdu news today &amp; watch live breaking news updates in Urdu from Pakistan, Sports, Entertainment. Enjoy Urdu news live stream &amp; your favorite shows on Geo News Urdu." name="description"/>
# <meta content="geo urdu news, geo news in urdu, urdu news, urdu updates, latest urdu news, جیو اردو نیوز, breaking news in urdu, geo tv urdu, geo news tv urdu, geo news, geo tv" name="keywords"/>
# <meta content="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu" property="og:title">
# <meta content="https://urdu.geo.tv/assets/front/images/image-share.jpg" property="og:image">
# <meta content="https://urdu.geo.tv/assets/front/images/image-share.jpg" property="og:image:secure_url">
# <meta content="image/jpeg" property="og:image:type">
# <meta content="700" property="og:image:width"/>
# <meta content="400" property="og:image:height"/>
# <meta content="Urdu News - Visit Geo News Urdu online to read latest urdu news today &amp; watch live breaking news updates in Urdu from Pakistan, Sports, Entertainment. Enjoy Urdu news live stream &amp; your favorite shows on Geo News Urdu." property="og:description"/>
# <meta content="https://urdu.geo.tv/" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@geonews_urdu" name="twitter:site"/>
# <meta content="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu" name="twitter:title"/>
# <meta content="Urdu News - Visit Geo News Urdu online to read latest urdu news today &amp; watch live breaking news updates in Urdu from Pakistan, Sports, Entertainment. Enjoy Urdu news live stream &amp; your favorite shows on Geo News Urdu." name="twitter:description"/>
# <meta content="https://urdu.geo.tv/assets/front/images/image-share.jpg" name="twitter:image"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-MJLJXLD');</script>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/128x128.png" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/192x192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/230x230.png" rel="icon" sizes="230x230" type="image/png"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/256x256.jpg" rel="icon" sizes="256x256" type="image/png"/>
# <link href="https://urdu.geo.tv/assets/front/images/gn-icons/geo-favicon.jpg" rel="shortcut icon"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="Geo News" name="apple-mobile-web-app-title"/>
# <meta content="https://urdu.geo.tv/assets/front/images/gn-icons/144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="#0D3975" name="theme-color"/>
# <link href="https://urdu.geo.tv/assets/front/css/notification.css" rel="stylesheet"/>
# <link href="https://urdu.geo.tv/manifest.json" rel="manifest"/>
# <link href="https://urdu.geo.tv/assets/front/ui/css/geo.css?v=98" rel="stylesheet" type="text/css">
# <link href="https://ramadan.geo.tv/ramadan-calendar" rel="canonical">
# <link href="https://ramadan.geo.tv/amp/ramadan-calendar" rel="amphtml"/>
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-1627489-1', 'auto');
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#     </script>
# <script type="text/javascript">
#         var _sf_async_config={};
#         /** CONFIGURATION START **/
#         _sf_async_config.uid = 49676;
#         _sf_async_config.domain = 'urdu.geo.tv';
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.sections = "home";  //CHANGE THIS
#         _sf_async_config.authors = '';    //CHANGE THIS
#         /** CONFIGURATION END **/
#
#     </script>
# <script>
#     function mobilecheck()
#     {
#       var check = false;
#       (function(a){if(/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a)||/1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0,4))) check = true;})(navigator.userAgent||navigator.vendor||window.opera);
#       return check;
#     }
# </script>
# <script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#         var FAILSAFE_TIMEOUT = 3300;
#     var PREBID_TIMEOUT = 1000;
#     var adUnits = [{
#         code: '/1063725/geo_urd_home_billboard_atf',
#         mediaTypes: {
#             banner: {
#                 sizes: [
#                     [970, 250],
#                     [970, 90],
#                     [728, 90],
#                     [320, 100]
#                 ]
#             }
#         },
#         bids: [{
#             bidder: 'ix',
#             params: {
#                 siteId: '405034',
#                 size: [970, 250]
#             }
#         },
#             {
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [970, 90]
#                 }
#             },
#             {
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [728, 90]
#                 }
#             },
#             {
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [320, 100]
#                 }
#             }]
#     },
#         {
#             code: '/1063725/geo_urd_home_rectangle_atf',
#             mediaTypes: {
#                 banner: {
#                     sizes: [[300, 250]]
#                 }
#             },
#             bids: [{
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [300, 250]
#                 }
#             }]
#         },
#         {
#             code: '/1063725/geo_urd_home_rectangle_btf',
#             mediaTypes: {
#                 banner: {
#                     sizes: [[300, 250]]
#                 }
#             },
#             bids: [{
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [300, 250]
#                 }
#             }]
#         },
#         {
#             code: '/1063725/geo_urd_Home_Mrectangle_atf',
#             mediaTypes: {
#                 banner: {
#                     sizes: [[300, 250]]
#                 }
#             },
#             bids: [{
#                 bidder: 'ix',
#                 params: {
#                     siteId: '405034',
#                     size: [300, 250]
#                 }
#             }]
#         }
#     ];
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     googletag.cmd.push(function() {
#         googletag.pubads().disableInitialLoad();
#     });
#
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#
#     /*pbjs.setConfig({
#     ix: {
#         timeout: 500
#     }
#     });*/
#
#     pbjs.que.push(function() {
#         pbjs.addAdUnits(adUnits);
#         pbjs.requestBids({
#             bidsBackHandler: initAdserver,
#             timeout: PREBID_TIMEOUT
#         });
#     });
#
#     function initAdserver() {
#         if (pbjs.initAdserverSet) return;
#         pbjs.initAdserverSet = true;
#         googletag.cmd.push(function() {
#             pbjs.que.push(function() {
#                 pbjs.setTargetingForGPTAsync();
#                 googletag.pubads().refresh();
#             });
#         });
#     }
#     // in case PBJS doesn't load
#     setTimeout(function() {
#         initAdserver();
#     }, FAILSAFE_TIMEOUT);
#
#     </script>
# <script type="text/javascript">
#     window.googletag = window.googletag || {cmd: []};
#     var interstitialSlot;
#     googletag.cmd.push(function() {
#
#         var mappingbillboard = googletag.sizeMapping().
#         addSize([1024, 0], [970, 90]).
#         addSize([768, 0], [970, 90]).
#         addSize([500, 0], [728, 90]).
#         addSize([0, 0], [320, 100]).
#         build();
#
#         var mappingbillboardhome = googletag.sizeMapping().
#         addSize([1024, 0], [[970, 250], [970, 90], [728, 90]]).
#         addSize([768, 0], [970, 90]).
#         addSize([500, 0], [728, 90]).
#         addSize([0, 0], [320, 100]).
#         build();
#
#         var mappingbillboardlatest = googletag.sizeMapping().
#         addSize([1024, 0], [728, 90]).
#         addSize([768, 0], [728, 90]).
#         addSize([500, 0], [336, 280]).
#         addSize([0, 0], [300, 250]).
#         build();
#
#         var mappingleaderboardb = googletag.sizeMapping().
#         addSize([1024, 0], [970, 90]).
#         addSize([768, 0], [970, 90]).
#         addSize([500, 0], [336, 280]).
#         addSize([0, 0], [300, 250]).
#         build();
#
#         //googletag.defineSlot('/1063725/Ramzan_Clock', [200, 260], 'div-gpt-ad-1556983892107-0').addService(googletag.pubads());
#                     googletag.defineSlot('/1063725/geo_urd_home_billboard_atf', [970, 90], 'div-gpt-ad-1523347624444-4').defineSizeMapping(mappingbillboardhome).setTargeting('pos', ['atf']).addService(googletag.pubads());
#             googletag.defineSlot('/1063725/geo_urd_home_billboard_btf', [970, 90], 'div-gpt-ad-1523347624444-5').defineSizeMapping(mappingleaderboardb).setTargeting('pos', ['btf']).addService(googletag.pubads());
#             googletag.defineSlot('/1063725/geo_urd_home_rectangle_atf', [300, 250], 'div-gpt-ad-1523347624444-6').setTargeting('pos', ['atf']).addService(googletag.pubads());
#             googletag.defineSlot('/1063725/geo_urd_home_rectangle_btf', [300, 250], 'div-gpt-ad-1523347624444-7').setTargeting('pos', ['btf']).addService(googletag.pubads());
#
#             if(mobilecheck())
#             {
#                 googletag.defineSlot('/1063725/geo_urd_Home_Mrectangle_atf', [300, 250], 'div-gpt-ad-1523516073626-1').setTargeting('pos', ['atf']).addService(googletag.pubads());
#             }
#
#             //googletag.defineSlot('/1063725/Geo_urd_Native_ATF', ['fluid'], 'div-gpt-ad-1566990166450-0').addService(googletag.pubads());
#             googletag.defineSlot('/1063725/geo_urdu/home/breaking_rectangle_atf', [300, 250], 'div-gpt-ad-1504958325151-0').addService(googletag.pubads());
#                             googletag.pubads().setTargeting("post_url_sha1","ecc09ae3b6dcddf7803aa59760f46f41e12cdb3a");
#         //googletag.pubads().enableSyncRendering();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
# </script>
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "url": "https://urdu.geo.tv//",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://urdu.geo.tv//search1?q={search_term_string}",
#     "query-input": "required name=search_term_string"
#   }
# }
#
# </script>
# <style>
#         .lazyloaded {
#             opacity: 1;
#         }
#         .lazyload {
#             opacity: 0;
#         }
#         .video-js.vjs-fluid {
#             min-height: 300px;
#             min-width: 320px;
#         }
#     </style>
# <script>
#             /*(function(h,e,a,t,m,p) {
#             m=e.createElement(a);m.async=!0;m.src=t;
#             p=e.getElementsByTagName(a)[0];p.parentNode.insertBefore(m,p);
#             })(window,document,'script','https://u.heatmap.it/log.js');*/
#         </script>
# <script crossorigin="anonymous" integrity="sha256-CSXorXvZcTkaix6Yvo6HppcZGetbYMGWSFlBw8HfCJo=" src="https://code.jquery.com/jquery-3.4.1.min.js"></script>
# <script>
#             function ucfirst(str,force){
#                 try{
#                     str=force ? str.toLowerCase() : str;
#                     return str.replace(/(\b)([a-zA-Z])/,
#                         function(firstLetter){
#                             return   firstLetter.toUpperCase();
#                         });
#                 }catch (e) {
#
#                 }
#
#             }
#         function analyticsFunc(element){
#             event.preventDefault();
#
#             var eventName = $(element).data('event');
#             var eventAction = $(element).data('event_action');
#             var page_type = $(element).data('page_type');
#
#             // console.log(eventName)
#             // console.log(eventAction)
#             // console.log(page_type)
#
#
#             if(eventName == 'tvc_top_navigation'){
#                 // console.log('asd')
#                 dataLayer.push({'event':eventName,
#                     'eventCategory':'top_navigation_menu',
#                     'eventAction':ucfirst(eventAction,true),
#                     'eventLabel':'NA',
#                     'language':'Urdu',
#                     'page_type':page_type
#                 });
#
#
#             }else if(eventName == 'tvc_bottom_navigation'){
#                 //console.log('asadsd')
#                 dataLayer.push({'event':eventName,
#                     'eventCategory':'bottom_navigation_menu',
#                     'eventAction':ucfirst(eventAction,true),
#                     'eventLabel':'NA',
#                     'language':'Urdu',
#                     'page_type':ucfirst(page_type,true)
#                 });
#
#             }
#
#
#             window.location.href = $(element).attr('href');
#
#         }
#         function shareVideo(element) {
#             // console.log(element)
#
#             var eventLabel = $(element).data('event_label')
#             var video_title = $(element).data('video_title')
#             var category = $(element).data('category')
#             var video_id = $(element).data('video_id')
#
#             // console.log(eventLabel)
#             // console.log(video_title)
#             // console.log(category)
#             // console.log(video_id)
#
#             dataLayer.push({'event':'tvc_video',
#                 'eventCategory':'video',
#                 'eventAction':'share',
#                 'eventLabel':ucfirst(eventLabel,true),
#                 'language':'English',
#                 'page_type':'Video',
#                 'page_category':ucfirst(category,true),
#                 'sub_category':'NA',
#                 'video_title':video_title,
#                 'video_id':video_id
#             });
#         }
#         function tvc_video_play(element){
#             var video_id = $(element).data('video_id');
#             // var watch_duration = $(element).data('watch_duration');
#             var video_title = $(element).data('video_title');
#             // var page_category = $(element).data('page_category');
#             // var sub_category = $(element).data('sub_category');
#             // console.log(video_id)
#             // console.log(video_title)
#             dataLayer.push({'event':'tvc_video',
#                 'eventCategory':'video',
#                 'eventAction':'play',
#                 'eventLabel':ucfirst(video_title,true),
#                 'video_id':video_id
#             });
#         }
#             setTimeout(function () {
#
#             try{
#                 $('video-js').attr('id','videoplayer')
#                 var myPlayer = videojs('videoplayer');
#
#                 myPlayer.on('play', () => {
#
#                     var category = ucfirst($('#category').val(),true);
#                     var sub_category = ucfirst($('#sub_category').val());
#                     var video_title = $('#video_title').val();
#                     console.log('asdasdas');
#                     var watch_duration = 0.0;
#                     watch_duration = myPlayer.currentTime()
#
#                     dataLayer.push({'event':'tvc_video',
#                         'eventCategory':'video',
#                         'eventAction':'play',
#                         'eventLabel':video_title,
#                         'language':'Urdu',
#                         'page_type':'Detail page',
#                         'page_category':category,
#                         'sub_category':sub_category,
#                         'watch_duration':watch_duration,
#                         'video_time_at': watch_duration
#                     });
#                 });
#
#                 myPlayer.on('pause', () => {
#
#                     var category = ucfirst($('#category').val(),true);
#                     var sub_category = ucfirst($('#sub_category').val());
#                     var video_title = $('#video_title').val();
#                     console.log('afsasf');
#                     var watch_duration = 0.0;
#                     watch_duration = myPlayer.currentTime()
#
#                     dataLayer.push({'event':'tvc_video',
#                         'eventCategory':'video',
#                         'eventAction':'pause',
#                         'eventLabel':video_title,
#                         'language':'Urdu',
#                         'page_type':'Detail page',
#                         'page_category':category,
#                         'sub_category':sub_category,
#                         'watch_duration':watch_duration,
#                         'video_time_at': watch_duration
#                     });
#                 });
#
#             }catch(e){
#
#             }
#             },2000)
#             try{
#                 var lis = $('.rpClass').find('ul > li');
#                 //  var i = 0;
#                 // console.log(lis);
#
#                 $.each(lis,function (k,v) {
#                     // i++;
#                     //   console.log(k);
#                     // console.log($(v).children('a').first().text())
#                     $(v).children('a').first().on('click',function () {
#
#                         dataLayer.push({
#                             'event': 'article_clicks',
#                             'eventCategory': 'article_clicks',
#                             'eventAction': 'readMore_click',
#                             'eventLabel': parseInt(k) + 1,
#                             'article_name': $(v).children('a').first().text()
#                         })
#
#                     })
#                 })
#
#             }catch(e){
#
#             }
#
#
#
#             function tester(){
#             var category = $('#category').val();
#             var sub_category = $('#sub_category').val();
#             var video_title = $('#video_title').val();
#             var video_id = $('#video_id').val();
#
#
#             try{
#                 var myPlayer = videojs('videoplayer');
#                 var watch_duration = 0.0;
#                 watch_duration = myPlayer.currentTime()
#                 dataLayer.push({'event':'tvc_video',
#                     'eventCategory':'video',
#                     'eventAction':'close',
#                     'eventLabel':video_title,
#                     'language':'English',
#                     'page_type':'Detail page',
#                     'page_category':category,
#                     'sub_category':sub_category,
#                     'watch_duration':watch_duration,
#                     'video_time_at': watch_duration
#                 });
#
#             }catch (e) {
#
#             }
#         }
#         window.onbeforeunload = function(){
#             tester()
#             console.log('Are you sure you want to leave?')
#             //    return 'Are you sure you want to leave?';
#         }
#
#
#         function millisToMinutesAndSeconds(millis) {
#             var minutes = Math.floor(millis / 60000);
#             var seconds = ((millis % 60000) / 1000).toFixed(0);
#             return minutes + ":" + (seconds < 10 ? '0' : '') + seconds;
#         }
#     </script>
# </link></link></meta></meta></meta></meta></meta></meta></head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MJLJXLD" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
#         dataLayer.push({
#             'event':'pageview',
#             'language':'Urdu',
#             'page_type':'Home Page'  ,
#             'ad_present' : 'Yes'
#         });
#     </script>
# <style type="text/css">
#     .ramzan_clock_ads{
#         height:auto; width:auto;position: fixed; z-index: 99;bottom: 5%;left:0;
#     }
# </style>
# <div id="transparent_div"></div>
# <div class="homebg">
# <style>
#     header nav ul.menu li.election-links,
#     .sidenav .inner-scroller ul li.election-links
#     {
#         display: none;
#     }
# </style>
# <div class="leftOverlay" id="leftOverlay" onclick="closeNav()"></div>
# <div class="sidenav" id="mySidenav">
# <style>
#     header nav ul.menu li.election-links,
#     .sidenav .inner-scroller ul li.election-links
#     {
#         display: none;
#     }
# </style>
# <div class="inner-scroller">
# <div class="column-left">
# <div class="left-stick" id="leftstickmenu">
# <div class="logo-section">
# <a class="logo open-section" data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)">
# <img class="responsive-logo-white" src="https://urdu.geo.tv//assets/front/images/urdu-logo-white.png?v=655"/>
# </a>
# </div>
# <div class="menu-area" id="style-1">
# <ul>
# <li class="election-links"><a class="open-section" href="https://urdu.geo.tv/" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a></li>
# <li class="election-links"><a class="open-section" href="https://urdu.geo.tv/election/constituency" title="انتخابی حلقے">انتخابی حلقے</a></li>
# <li class="election-links"><a class="open-section" href="https://urdu.geo.tv/election/candidates" title="امیدوار">امیدوار</a></li>
# <li class="election-links"><a class="open-section" href="https://urdu.geo.tv/election/results" title="نتائج">نتائج</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="KPK Election" data-page_type="Listing Page" href="https://urdu.geo.tv/election/kp-localbodies2021/" onclick="analyticsFunc(this)" style="color:#f7941e;" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">کے پی بلدیاتی الیکشن</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Latest News" data-page_type="Listing Page" href="https://urdu.geo.tv/latest-news" onclick="analyticsFunc(this)" title="Latest Urdu News Live today &amp; online breaking news updates in Urdu from Pakistan, Sports, Entertainment - Geo News Urdu">تازہ ترین</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://urdu.geo.tv/category/pakistan" onclick="analyticsFunc(this)" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">پاکستان</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="World" data-page_type="Listing Page" href="https://urdu.geo.tv/category/world" onclick="analyticsFunc(this)" title="World Urdu News - Latest live breaking World News updates today in Urdu by Geo News Urdu">دنیا</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Sports" data-page_type="Listing Page" href="https://urdu.geo.tv/category/sports" onclick="analyticsFunc(this)" title="Sports Urdu News - Latest live Sports World News updates today in Urdu by Geo News Urdu">کھیل</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Entertainment" data-page_type="Listing Page" href="https://urdu.geo.tv/category/entertainment" onclick="analyticsFunc(this)" title="Entertainment Urdu News - Latest live Entertainment World News updates today in Urdu by Geo News Urdu">انٹرٹینمنٹ</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Business" data-page_type="Listing Page" href="https://urdu.geo.tv/category/business" onclick="analyticsFunc(this)" title="Business Urdu News - Latest live Business World News updates today in Urdu by Geo News Urdu">کاروبار</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Health" data-page_type="Listing Page" href="https://urdu.geo.tv/category/health" onclick="analyticsFunc(this)" title="Health Urdu News - Latest live Health World News updates today in Urdu by Geo News Urdu">صحت</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Amazing" data-page_type="Listing Page" href="https://urdu.geo.tv/category/amazing" onclick="analyticsFunc(this)" title="Amazing Urdu News - Latest live Amazing World News updates today in Urdu by Geo News Urdu">دلچسپ و عجیب</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Blog" data-page_type="Listing Page" href="https://urdu.geo.tv/category/blog" onclick="analyticsFunc(this)" title="Urdu Blogs from Pakistan on Geo News Urdu">بلاگ</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="TV Shows" data-page_type="Listing Page" href="https://urdu.geo.tv/tv-shows" onclick="analyticsFunc(this)" title="TV Shows">شوز</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Videos" data-page_type="Listing Page" href="https://urdu.geo.tv/videos" onclick="analyticsFunc(this)" title="Urdu Videos News Packages - Latest live video updates of breaking news today in Urdu by Geo News Urdu">ویڈیوز</a></li>
# <li><a class="contactus" href="#_">رابطہ کریں </a></li>
# <li>
# <div style="display: table;margin: 0 auto;width: 150px;">
# <a class="slide-bell top-head-bell-responsive bell-temp" href="javascript:void(0)"><svg height="20" version="1.1" viewbox="0 0 511.63 511.63" width="20" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"> <g> <path d="M411.404,288.506c-18.455-45.014-27.685-92.455-27.685-142.325c0-31.405-9.131-56.337-27.398-74.802 c-18.28-18.464-43.406-29.602-75.383-33.407c1.52-3.424,2.279-6.945,2.279-10.562c0-7.614-2.663-14.091-7.991-19.416 C269.898,2.663,263.427,0,255.812,0c-7.61,0-14.083,2.663-19.414,7.994c-5.33,5.329-7.993,11.802-7.993,19.416 c0,3.617,0.76,7.135,2.285,10.562c-31.977,3.809-57.103,14.942-75.375,33.407c-18.271,18.464-27.406,43.396-27.406,74.802 c0,49.87-9.229,97.311-27.694,142.325c-18.464,45.015-45.776,82.847-81.942,113.492c0,9.896,3.617,18.463,10.85,25.693 c7.232,7.231,15.796,10.852,25.697,10.852h127.907c0,20.178,7.135,37.404,21.411,51.675c14.277,14.273,31.504,21.412,51.678,21.412 c20.177,0,37.404-7.139,51.675-21.412c14.273-14.271,21.412-31.497,21.412-51.675H456.81c9.897,0,18.47-3.613,25.694-10.852 c7.234-7.23,10.852-15.797,10.852-25.693C457.196,371.353,429.881,333.521,411.404,288.506z M255.816,488.787 c-13.894,0-25.747-4.896-35.548-14.698c-9.801-9.804-14.703-21.658-14.703-35.553c0-3.046,1.524-4.568,4.568-4.568 c3.046,0,4.57,1.522,4.57,4.568c0,11.231,4.043,20.889,12.132,28.982c8.091,8.094,17.749,12.135,28.98,12.135 c3.046,0,4.575,1.53,4.575,4.569C260.392,487.268,258.862,488.787,255.816,488.787z"></path> </g> </svg></a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div></div>
# <header>
# <div class="mobile-header">
# <div class="mobile-left">
# <div class="mobile-nav">
# <span class="mob-menu-icon" onclick="openNav()">
# <img class="mob-blue-icon" src="https://urdu.geo.tv/assets/front/images/Menu-blue.svg?v=23"/>
# <img class="mob-white-icon" src="https://urdu.geo.tv/assets/front/images/Menu-white.svg?v=23"/>
# <img class="mob-green-icon" src="https://urdu.geo.tv/assets/front/images/Menu-green.svg?v=239"/>
# </span>
# </div>
# </div>
# <div class="mobile-header-left">
# <div class="logo">
# <a class="open-section" href="https://urdu.geo.tv/">
# <div class="logo-white"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/> </div>
# <div class="logo-blck"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/> </div>
# <div class="logo-green" style="display: none"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo-green.svg"/> </div>
# </a>
# </div>
# </div>
# <div class="header-right">
# <ul>
# <li>
# <div class="live-btn">
# <a data-event="tvc_top_navigation" data-event_action="live_tv" data-page_type="Homepage" href="http://live.geo.tv/" onclick="analyticsFunc(this)" target="_blank">
# <div class="icon" style="display: block">
# <img src="https://urdu.geo.tv/assets/front/images/GEOURDU-TV-ICON.png"/>
# </div>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="desktop-header">
# <div class="header_top">
# <div class="container">
# <div class="h_top_center">
# <div class="logo-white"><a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/></a> </div>
# <div class="logo-blck"><a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/></a> </div>
# </div>
# </div>
# </div>
# <div class="header_bottom">
# <div class="container">
# <div class="h_b_logo">
# <a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/logo_.svg?v=239"/></a>
# </div>
# <nav>
# <a href="#" id="close-nav">X</a>
# <ul class="menu">
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="live_tv" data-page_type="Homepage" href="https://live.geo.tv/" onclick="analyticsFunc(this)" target="_blank" title="Live TV"><img src="https://urdu.geo.tv/assets/front/images/GEOURDU-TV-ICON.png"/></a></li>
# <li class="active"><a class="open-section" data-event="tvc_top_navigation" data-event_action="Home" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Latest" data-page_type="Listing Page" href="https://urdu.geo.tv/latest-news" onclick="analyticsFunc(this)" title="Latest Urdu News Live today &amp; online breaking news updates in Urdu from Pakistan, Sports, Entertainment - Geo News Urdu">تازہ ترین</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="KPK Election" data-page_type="Listing Page" href="https://urdu.geo.tv/election/kp-localbodies2021/" onclick="analyticsFunc(this)" style="color: red;" title="Pakistan Urdu News - Latest live KPK Election News updates today in Urdu by Geo News Urdu">کے پی بلدیاتی الیکشن</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://urdu.geo.tv/category/pakistan" onclick="analyticsFunc(this)" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">پاکستان</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="World" data-page_type="Listing Page" href="https://urdu.geo.tv/category/world" onclick="analyticsFunc(this)" title="World Urdu News - Latest live breaking World News updates today in Urdu by Geo News Urdu">دنیا</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Sports" data-page_type="Listing Page" href="https://urdu.geo.tv/category/sports" onclick="analyticsFunc(this)" title="Sports Urdu News - Latest live Sports World News updates today in Urdu by Geo News Urdu">کھیل</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Entertainment" data-page_type="Listing Page" href="https://urdu.geo.tv/category/entertainment" onclick="analyticsFunc(this)" title="Entertainment Urdu News - Latest live Entertainment World News updates today in Urdu by Geo News Urdu">انٹرٹینمنٹ</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Business" data-page_type="Listing Page" href="https://urdu.geo.tv/category/business" onclick="analyticsFunc(this)" title="Business Urdu News - Latest live Business World News updates today in Urdu by Geo News Urdu">کاروبار</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="TV Shows" data-page_type="Listing Page" href="https://urdu.geo.tv/tv-shows" onclick="analyticsFunc(this)" title="TV Shows">شوز</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="Videos" data-page_type="Listing Page" href="https://urdu.geo.tv/videos" onclick="analyticsFunc(this)" title="Urdu Videos News Packages - Latest live video updates of breaking news today in Urdu by Geo News Urdu">ویڈیوز</a></li>
# <li><a class="open-section" data-event="tvc_top_navigation" data-event_action="GeoEnglish_click" data-page_type="Homepage" href="https://geo.tv/" onclick="analyticsFunc(this)" target="_blank" title="GEO TV"><img src="https://urdu.geo.tv/assets/front/images/GEOEnglish-ICON.png"/></a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <style>
#     .coronavirus_banner{
#         width:100%;
#         float:right;
#         background:#383838;
#         margin-bottom: 20px;
#
#     }
#     .coronavirus_banner .c_b_title{
#         display: inline-block;
#         font-size: 32px;
#         line-height: 34px;
#         background-color: #f38120;
#         padding: 10px 10px 0 0;
#         float: left;
#         width: 100%;
#     }
#     .v_b_left{
#         width: 200px;
#         float: right;
#     }
#     .coro_icone{
#         float: right;
#         width: 60px;
#         height: 60px;
#         margin-left: -28px;
#     }
#     .vb_left_box{
#         float:right;
#         width: 93%;
#         width: -webkit-calc(100% - 60px - 1%);
#         width: calc(100% - 60px - 1%);
#     }
#     .cc_tttxt{
#         float: right;
#         width: 100%;
#         font-weight: 700;
#     }
#     .c_red{
#         color: #fff;
#         width: 100%;
#         float: right;
#     }
#     .p_green{
#         width: 100%;
#         float: right;
#         color: #000000;
#         line-height: 20px;
#         font-size: 13px;
#         text-align: center;
#     }
#     .c_c{
#         font-size: 12px;
#         color: #f48420;
#         line-height: 18px;
#         margin-top: 0;
#         float: right;
#     }
#     .left_number{
#          font-size: 55px;
#         color: #f48420;
#         line-height: 63px;
#         display: inline-block;
#         margin-top: 6px;
#     }
#     .v_b_right{
#         width: 93%;
#         width: -webkit-calc(100% - 200px - 0%);
#         width: calc(100% - 200px - 0%);
#         float:right;
#     }
#     .v_b_right ul{
#         padding: 0;
#         margin: 0;
#     }
#     .v_b_right ul li{
#         width: 14.28%;
#         margin: 0;
#         float: right;
#         text-align: center;
#         color: #ccc;
#         font-size: 30px;
#         list-style: none;
#     }
#     .vb_right_number {
#         display: block;
#         color: #f48420;
#         font-size: 16px;
#         line-height: 13px;
#         margin: 15px auto 0 0;
#         text-align: center;
#         text-transform: uppercase;
#         font-weight: 500;
#     }
#
#     .vb_right_text{
#         display: inline-block;
#         color: #fff;
#         line-height: 28px;
#         font-size: 26px;
#         text-align: center;
#         font-family: sans-serif;
#         font-weight: bold;
#     }
#     .c_b_tc{
#         background-color: #f38120;
#     }
#     .c_b_tc span.vb_right_text, .c_b_recovered_cases span.vb_right_number, .c_b_confirmed_cases span.vb_right_number{
#         color: #fff;
#     }
#     .c_b_tc span.vb_right_number, .c_b_recovered_cases span.vb_right_text, .c_b_confirmed_cases span.vb_right_text{
#         color: #fff;
#     }
#     .c_b_recovered_cases {
#         background-color: #cf161c;
#         background-image: linear-gradient(to right, #87c049 , #16924a);
#     }
#     .c_b_confirmed_cases {
#         background-color: #cf161c;
#         background-image: linear-gradient(to right, #a20d11 , #e81825);
#     }
#     @media (max-width: 1200px){
#         .vb_right_text{
#             font-size: 20px;
#         }
#     }
#     @media (max-width: 992px){
#         .coronavirus_banner{
#             height: 140px;
#             position: relative;
#         }
#         .v_b_right ul li {
#             width: 20%;
#         }
#         .v_b_right ul li.c_b_recovered_cases {
#             position: absolute;
#             left: 0;
#             bottom: 0;
#             width: 50%;
#         }
#         .v_b_right ul li.c_b_confirmed_cases {
#             position: absolute;
#             right: 0;
#             bottom: 0;
#             width: 50%;
#         }
#     }
#     @media (max-width: 767px){
#         .vb_right_text {
#             font-size: 20px;
#         }
#         .vb_right_number {
#             font-size: 14px;
#         }
#         .coronavirus_banner .container{
#             padding: 0;
#         }
#     }
#     @media (max-width: 600px){
#         .coronavirus_banner {
#             height: auto;
#         }
#         .coronavirus_banner .c_b_title{
#             line-height: 51px;
#         }
#         .v_b_left {
#             width: 100%;
#         }
#         .v_b_right{
#             width: 100%;
#         }
#         .cc_tttxt{
#             width: 200px;
#         }
#         .v_b_right ul li.c_b_recovered_cases {
#             position: absolute;
#             left: 0;
#             bottom: inherit;
#             width: 50%;
#             top: 0;
#             height: 40px;
#         }
#         .v_b_right ul li.c_b_confirmed_cases {
#             position: absolute;
#             right: inherit;
#             bottom: inherit;
#             width: 50%;
#             top: 40px;
#             left: 0;
#             height: 40px;
#         }
#         .v_b_right ul li{
#             font-size: 20px;
#         }
#         .vb_right_number{
#             margin: 5px auto 0 0;
#             font-size: 12px;
#         }
#         .vb_right_number {
#
#         }
#         .c_b_recovered_cases .vb_right_number,.c_b_confirmed_cases .vb_right_number{
#             margin-top: 2px;
#         }
#     }
#     @media (max-width: 400px){
#         .v_b_right ul li, .vb_right_text{
#             font-size: 14px;
#         }
#         .vb_right_number{
#             font-size: 10px;
#         }
#         .cc_tttxt {
#             width: auto;
#         }
#     }
# </style>
# <div style="width:100%;display:inline-block;text-align:center;">
# <a href="https://urdu.geo.tv/sites/top-news-stories-of-2021-in-pakistan/">
# <img src="https://urdu.geo.tv/sites/top-news-stories-of-2021-in-pakistan/img/GEO-banner-urdu.png" style="max-width:100%;"/>
# </a>
# </div>
# <section class="home_s_top">
# <div class="container">
# <div class="ads lb">
# <div id="div-gpt-ad-1523347624444-4" style="height:auto; width:auto;">
# <script async="" defer="" type="text/javascript">
#                     googletag.cmd.push(function () {
#                         googletag.display('div-gpt-ad-1523347624444-4');
#                     });
#                 </script>
# </div>
# </div>
# <div class="home_main_content">
# <div class="m_c_left" data-vr-zone="Home Featured Section">
# <ul>
# <li>
# <div class="m_pic">
# <a class="open-section" data-article_name="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" data-event_action="featured" data-position="1" data-vr-contentbox="Home Featured 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273610-" href="https://urdu.geo.tv/latest/273610-" onclick="getClick(this)" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/l_273610_022026_updates.jpg" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان"/>
# </a>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان&amp;url=https://urdu.geo.tv/latest/273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" data-event_action="featured" data-position="1" data-vr-contentbox="Home Featured 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273610-" href="https://urdu.geo.tv/latest/273610-" onclick="getClick(this)" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان">
# <h1 data-vr-headline="">نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان</h1>
# </a>
# </div>
# <div class="m_except">
# <p>ہائیکورٹ کو از خود نوٹس لیتے ہوئے شہباز شریف کو بلانا چاہیے تھا، نواز شریف کی واپسی کے لیے وزیراعظم نے اٹارنی جنرل کوہدایت جاری کی ہے: وزیر اطلاعات</p>
# </div>
# </li>
# <div class="top-ads-mob">
# <div class="ads mrec">
# <div id="div-gpt-ad-1523516073626-1" style="height:auto; width:auto;">
# <script async="" defer="" type="text/javascript">
#                                             googletag.cmd.push(function () {
#                                                 googletag.display('div-gpt-ad-1523516073626-1');
#                                             });
#                                         </script>
# </div>
# </div>
# </div>
# <li>
# <div class="heading">
# <a class="open-section" data-article_name="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" data-event_action="featured" data-position="2" data-vr-contentbox="Home Featured 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273619-" href="https://urdu.geo.tv/latest/273619-" onclick="getClick(this)" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب">
# <h2 data-vr-headline="">نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب</h2>
# </a>
# </div>
# <div class="m_pic">
# <a class="open-section" data-article_name="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" data-event_action="featured" data-position="2" data-vr-contentbox="Home Featured 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273619-" href="https://urdu.geo.tv/latest/273619-" onclick="getClick(this)" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273619_054008_updates.jpg" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب"/>
# </a>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273619-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب&amp;url=https://urdu.geo.tv/latest/273619-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# ...
# <li><a data-event="tvc_bottom_navigation" data-event_action="PRIVACY POLICY" data-page_type="Listing Page" href="https://www.geo.tv/privacy-policy-and-tos" onclick="analyticsFunc(this)" target="_blank">پرائیویسی پالیسی</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="ADVERTISING GUIDE" data-page_type="Listing Page" href="https://www.geo.tv/ratecardonline" onclick="analyticsFunc(this)" target="_blank">ایڈورٹائزنگ گائیڈ</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="FAQ DISTRIBUTION" data-page_type="Listing Page" href="https://www.geo.tv/faq-distribution" onclick="analyticsFunc(this)" target="_blank">عمومی سوالات(ڈسٹریبویشن)</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="CORPORATE PROFILE" data-page_type="Listing Page" href="https://www.geo.tv/corporate-profile" onclick="analyticsFunc(this)" target="_blank">کارپوریٹ پروفائل</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="FAQ (GENERAL)" data-page_type="Listing Page" href="http://203.176.191.38/marketing/capping/dailycapping.aspx" onclick="analyticsFunc(this)" target="_blank">عمومی سوالات(جنرل)</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO TV SATELLITE" data-page_type="Listing Page" href="https://www.geo.tv/faq#_" onclick="analyticsFunc(this)" target="_blank">جیوٹی وی سیٹلائٹ پیرامیٹرز</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="CAREER" data-page_type="Homepage" href="http://talent.geo.tv/" onclick="analyticsFunc(this)" target="_blank">کیرئیر</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO TALENT" data-page_type="Homepage" href="http://talent.geo.tv/" onclick="analyticsFunc(this)" target="_blank">جیو ٹیلنٹ</a></li>
# <li><a data-event="tvc_bottom_navigation" data-event_action="GEO ASOOL" data-page_type="Homepage" href="http://asool.geo.tv/" onclick="analyticsFunc(this)" target="_blank">جیو اصول</a></li>
# </ul>
# </div>
# <div class="ftr_col">
# <h1>ایپ ڈاؤن لوڈ کریں</h1>
# <ul>
# <li><p>جیو ٹی وی کی آفیشیل اینڈ رائیڈ ایپلیکیشن ۔ جیو نیوز لائیو دیکھئے،</p></li>
# <li><a class="apps" data-event="tvc_bottom_navigation" data-event_action="google play" data-page_type="Homepage" href="https://play.google.com/store/apps/details?id=com.imm.android.geourdu" onclick="analyticsFunc(this)" style="width: 48%;" target="_blank"><img alt="" src="https://urdu.geo.tv/assets/front/images/play_store.png"/></a>
# <a class="apps" data-event="tvc_bottom_navigation" data-event_action="app store" data-page_type="Homepage" href="https://itunes.apple.com/cy/app/com.imm.ios.geourdu/id1332608511" onclick="analyticsFunc(this)" style="width: 48%;" target="_blank"><img alt="" src="https://urdu.geo.tv/assets/front/images/app_store.png"/> </a>
# <a class="apps" data-event="tvc_bottom_navigation" data-event_action="app store" data-page_type="Homepage" href="https://appgallery.huawei.com/#/app/C101401651" onclick="analyticsFunc(this)" target="_blank"><img alt="" src="https://urdu.geo.tv/assets/front/images/huawei-app-logo.png"/> </a>
# </li>
# <h1 style="margin-top: 5px;">فولو کریں</h1>
# <li>
# <a class="follow" href="https://www.facebook.com/GeoUrduDotTv/" target="_blank"><img alt="facebook" src="https://urdu.geo.tv/assets/front/images/fb_round.png"/></a>
# <a class="follow" href="https://twitter.com/geonews_urdu" target="_blank"><img alt="twitter" src="https://urdu.geo.tv/assets/front/images/twitter_round.png"/></a>
# <a class="follow" href="https://www.youtube.com/user/geonews/" target="_blank"><img alt="youtube" src="https://urdu.geo.tv/assets/front/images/youtube_round.png"/></a>
# <a class="follow" href="https://www.instagram.com/geonewsdottv/" target="_blank"><img alt="instagram" src="https://urdu.geo.tv/assets/front/images/instagram-icon.png"/></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="copyright">
# <p>Copyright © 2022. Geo Television Network. All Rights Reserved.</p>
# </div>
# </footer>
# <div class="modal fade" id="contactPopup" role="dialog" style="display:none;    z-index: 9999999999;" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h3 class="modal-title">Contact us</h3>
# </div>
# <div class="modal-body">
# <table border="0" cellpadding="5" cellspacing="5">
# <thead></thead>
# <tbody>
# <tr>
# <td colspan="2" style="font-size: 15px;text-align: right; margin-bottom: 10px;">
# ایڈیٹر سے رابطہ کے لیے
# <br/>
# <a href="/cdn-cgi/l/email-protection#dcb9b8b5a8b3aebbb9b3f2a8aa9cb5b1b1bfb3aeacb3aebda8b9f2bfb3b1"><span class="__cf_email__" data-cfemail="6f0a0b061b001d080a00411b192f0602020c001d1f001d0e1b0a410c0002">[email protected]</span></a>
# </td>
# <td colspan="2" style="font-size: 15px;text-align: right; margin-bottom: 10px;">
# مارکیٹنگ اور سیلز ٹیم تک رسائی کے لیے
#  <br/>
# <a href="/cdn-cgi/l/email-protection#e59684898096a58c8888868a97958a97849180cb868a88"><span class="__cf_email__" data-cfemail="582b39343d2b183135353b372a28372a392c3d763b3735">[email protected]</span></a>
# </td>
# <td colspan="2" style="font-size: 15px;text-align: right; margin-bottom: 10px;">
# دیگر معلومات کے لیے
# <br/>
# <a href="/cdn-cgi/l/email-protection#2b585e5b5b44595f6b4246464844595b44594a5f4e05484446"><span class="__cf_email__" data-cfemail="74070104041b0600341d1919171b06041b061500115a171b19">[email protected]</span></a>
# </td>
# <td colspan="2" style="font-size: 15px;text-align: right;">
# ای میل کے علاوہ آپ درج ذیل فارم بھی پُر کر سکتے ہیں
# </td>
# </tr>
# <tr>
# <td>
# Name <br/>
# <input class="txtfield" id="contact_name" maxlength="1000" name="contact_name" type="text"/>
# </td>
# </tr>
# <tr>
# <td>
# Email <br/>
# <input class="txtfield" id="contact_email" maxlength="1000" name="contact_email" type="text"/>
# </td>
# </tr>
# <tr>
# <td>
# Phone
# <br/> <input class="txtfield" id="contact_phone" maxlength="1000" name="contact_phone" type="text"/>
# </td>
# </tr>
# <tr>
# <td>
# Related to <br/>
# <select class="combofield" id="contact_related" name="contact_name">
# <option value="Contact Editor">Contact Editor</option>
# <option value="Sales Inquiry">Sales Inquiry</option>
# <option value="Report an Error">Report an Error</option>
# <option value="Suggestion/Feedback">Suggestion/Feedback</option>
# </select>
# </td>
# </tr>
# <tr>
# <td>
# Message <br/>
# <textarea class="txtarea" id="contact_message" name="contact_message"></textarea>
# </td>
# </tr>
# <tr>
# <td>
# <div class="g-recaptcha" data-sitekey="6LfZ5EEUAAAAAOmkPBwUqhx5JBkCua3NPHa7Llih"></div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="modal-footer">
# <input class="btn btn-primary" id="filterSubmit" name="filterSubmit" type="submit" value="Submit"/>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="https://www.google.com/recaptcha/api.js"></script>
# </div>
# </div>
# </div>
# <style type="text/css">
#     .modal-open{
#         overflow: hidden !important;
#     }
#     #contactPopup {
#         font-family: sans-serif;
#         font-size: 14px;
#         text-align: left;
#         direction: ltr;
#     }
#     #contactPopup h3{
#         font-weight: bold;
#     }
#     #contactPopup .modal-header{
#         padding: 10px;
#     }
#     #contactPopup table{
#         width: 70%;
#         margin: 0 auto;
#     }
#     #contactPopup table tr{
#         padding-bottom: 10px;
#         float: left;
#         width: 100%;
#     }
#     #contactPopup table tr td{
#         width: 100%;
#         float: left;
#     }
#     #contactPopup table tr td .txtfield, #contactPopup table tr td .combofield{
#         width: 100%;
#         padding: 5px 10px;
#     }
#     #contactPopup table tr td .txtarea{
#         width: 100%;
#         padding: 5px 10px;
#         height: 90px;
#     }
#     #contactPopup .modal-footer{
#         text-align: center;
#         position: relative;
#     }
#     #contactPopup .modal-footer #filterSubmit{
#         padding: 6px 15px;
#         background-color: #000;
#         border-color: #ccc;
#     }
#     #contactPopup .error_contact{
#         color: #f00;
#         font-size: 11px;
#     }
#     .frm_submit_msg{
#         margin-bottom: 8px;
#         color: #0f9c2e;
#     }
# </style></div>
# <script src="https://urdu.geo.tv/assets/front/ui/js/thirdparty.js"></script>
# <script src="https://urdu.geo.tv/assets/front/ui/js/my.js"></script>
# <script type="text/javascript">
#     var BaseURL = 'https://urdu.geo.tv/';
#     var Page = 'home';
#     var sg = '';
# </script>
# <script src="https://urdu.geo.tv/assets/front/js/mycustom.js?id=123" type="text/javascript"></script>
# <script src="https://urdu.geo.tv/assets/front/js/sidbildadada.js?id=12345678" type="text/javascript"></script>
# <script src="https://urdu.geo.tv/assets/front/js/sw-app.js?id=1234" type="text/javascript"></script>
# <script src="https://urdu.geo.tv/assets/front/js/lazysizes.min.js?v=1" type="text/javascript"></script>
# <script src="https://urdu.geo.tv/assets/front/js/d3/d3/d3.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://urdu.geo.tv/assets/front/js/d3/d3-parliament/d3-parliament.min.js" type="text/javascript"></script>
# <script src="https://urdu.geo.tv/assets/front/js/d3/d3_app.js?abcdefgh" type="text/javascript"></script>
# <div class="geo-news-panel fixed-side-button" style="right: -400px;">
# <div class="buttonBody"><a class="close-side-button closeSideBar" href="javascript:void(0)"><i class="fa fa-times"></i></a>
# <h2>Notification Management</h2>
# <hr/>
# <div class="category-body">
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="pakistan"/> <span>پاکستان</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="world"/><span>دنیا</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="business"/> <span>کاروبار</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="sports"/> <span>کھیل</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="entertainment"/> <span>انٹرٹینمنٹ</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="health"/> <span>صحت و سائنس</span>
# <div class="clearfix"></div>
# </div>
# <div class="column-category-vertical"><input class="subscription_categories" disabled="" name="categories[]" type="checkbox" value="amazing"/> <span>دلچسپ و عجیب</span>
# <div class="clearfix"></div>
# </div>
# </div>
# <button class="btn btn-primary saveCategories disable" type="button">Save changes</button>
# <hr/>
# <div class="sub-section" for="subsChecked"><input class="subscribe-notifications" id="subsChecked" type="checkbox"/><span>ڈیسک ٹاپ نوٹیفکیشن کے لیے سبسکرائب کریں</span>
# <div class="clearfix"></div>
# </div><a class="powered-text" href="http://immcorporate.com/" target="_blank">Powered by IMM</a></div>
# </div>
# <style>
#         /*.slide-bell.bell-temp.top-head-bell{display:none!important;}*/
#
#         .slide-bell.top-head-bell-responsive.bell-temp{width: 50px  !important;height: 50px !important;    margin: 15px auto !important;float: none !important;line-height: 70px !important;}
#         .slide-bell.top-head-bell-responsive.bell-temp svg{
#             width: 40px !important;
#             height: 30px !important;
#         }
#         .onesignal-bell-container{display: none !important; visibility: hidden !important; left: -500px !important;}
# </style>
# <script src="https://www.gstatic.com/firebasejs/7.1.0/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.1.0/firebase-analytics.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.1.0/firebase-messaging.js"></script>
# <script src="https://urdu.geo.tv/assets/front/js/push_notification.js?v=1.4"></script>
# <style>
#     .hide_column {
#         display : none !important;
#     }
#
#     .flourish-credit{
# 	display : none !important;
# 	}
# </style>
# <script type="text/javascript">
#     $(document).ready(function() {
#
#         if($('.vote_leading').length > 0){
#
#             var checkleading = 0;
#             setInterval(function(){
#                 if(checkleading == 0){
#                     $('.vote_leading').parents('.parent_vote_bar').addClass('show_leading_text');
#                     checkleading = 1;
#                 }
#                 else{
#                     $('.parent_vote_bar').removeClass('show_leading_text');
#                     checkleading = 0;
#                 }
#             }, 3000);
#         }
#
#         if (typeof $("body").find("#byelection_table").attr("id") !== "undefined")
#         {
#             $('#byelection_table').DataTable( {
#                 "columns": [
#                     { className: "hide_column" },
#                     null,
#                     null,
#                     null,
#                     null,
#                     null
#                 ],
#                 "order": [[ 0, "asc" ]],
#                 "lengthMenu": [[10, 25, 50, -1], [10, 25, 50, "All"]],
#                 "pageLength":15,
#                 "bLengthChange": false,
#                 "bInfo": false,
#                 "oLanguage": {
#                     "sSearch": ""
#                 },
#                 responsive: true
#             });
#         }
#         if (typeof $("body").find("#election_table").attr("id") !== "undefined")
#         {
#             $('#election_table').DataTable( {
#                 "columns": [
#                     { className: "hide_column" },
#                     null,
#                     null,
#                     null
#                 ],
#                 "order": [[ 0, "asc" ]],
#                 "lengthMenu": [[10, 25, 50, -1], [10, 25, 50, "All"]],
#                 "pageLength":50,
#                 "bLengthChange": false,
#                 "bInfo": false,
#                 "oLanguage": {
#                     "sSearch": ""
#                 },
#                 responsive: true
#             });
#         }
#         if (typeof $("body").find(".dataTables_filter").attr("class") !== "undefined")
#         {
#             $('.dataTables_filter input[type="search"]').attr('placeholder', 'Search Constituency / Candidate Name').css({
#                 'width': '250px',
#                 'display': 'inline-block'
#             });
#         }
#     });
#
#     function getClick(element) {
#       //  event.preventDefault();
#         var eventAction = $(element).data('event_action');
#         var position = $(element).data('position');
#         var article_name = $(element).data('article_name');
#         dataLayer.push({
#             'event': 'article_clicks',
#             'eventCategory': 'article_clicks',
#             'eventAction': eventAction, //eg: featured/topstories
#             'eventLabel': position,
#             'article_name': article_name
#         })
#
#        // window.location.href = $(element).attr('href')
#     }
# </script>
# <script>
#     /*navigator.serviceWorker.getRegistrations().then(function(registrations) {
#       for(let registration of registrations) {
#         if(registration.scope != 'https://urdu.geo.tv/firebase-cloud-messaging-push-scope'){
#           registration.unregister()
#         }
#         else{
#           //registration.update()
#         }
#       }
#     });*/
# </script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6c760c0f8ec201c8","token":"8291e380a9fa4889a56779ece7862f9c","version":"2021.12.0","si":100}' defer="" integrity="sha512-Gi7xpJR8tSkrpF7aordPZQlW2DLtzUlZcumS8dMQjwDHEnw9I7ZLyiOj/6tZStRBGtGgN6ceN6cMH8z7etPGlw==" src="https://static.cloudflareinsights.com/beacon.min.js/v652eace1692a40cfa3763df669d7439c1639079717194"></script>
# </body>
# </html>
# >

# %%
anchors = soup.find_all('a')

# %%
print(anchors)
# Out:
# [<a class="logo open-section" data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)">
# <img class="responsive-logo-white" src="https://urdu.geo.tv//assets/front/images/urdu-logo-white.png?v=655"/>
# </a>, <a class="open-section" href="https://urdu.geo.tv/" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a>, <a class="open-section" href="https://urdu.geo.tv/election/constituency" title="انتخابی حلقے">انتخابی حلقے</a>, <a class="open-section" href="https://urdu.geo.tv/election/candidates" title="امیدوار">امیدوار</a>, <a class="open-section" href="https://urdu.geo.tv/election/results" title="نتائج">نتائج</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="KPK Election" data-page_type="Listing Page" href="https://urdu.geo.tv/election/kp-localbodies2021/" onclick="analyticsFunc(this)" style="color:#f7941e;" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">کے پی بلدیاتی الیکشن</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Latest News" data-page_type="Listing Page" href="https://urdu.geo.tv/latest-news" onclick="analyticsFunc(this)" title="Latest Urdu News Live today &amp; online breaking news updates in Urdu from Pakistan, Sports, Entertainment - Geo News Urdu">تازہ ترین</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://urdu.geo.tv/category/pakistan" onclick="analyticsFunc(this)" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">پاکستان</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="World" data-page_type="Listing Page" href="https://urdu.geo.tv/category/world" onclick="analyticsFunc(this)" title="World Urdu News - Latest live breaking World News updates today in Urdu by Geo News Urdu">دنیا</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Sports" data-page_type="Listing Page" href="https://urdu.geo.tv/category/sports" onclick="analyticsFunc(this)" title="Sports Urdu News - Latest live Sports World News updates today in Urdu by Geo News Urdu">کھیل</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Entertainment" data-page_type="Listing Page" href="https://urdu.geo.tv/category/entertainment" onclick="analyticsFunc(this)" title="Entertainment Urdu News - Latest live Entertainment World News updates today in Urdu by Geo News Urdu">انٹرٹینمنٹ</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Business" data-page_type="Listing Page" href="https://urdu.geo.tv/category/business" onclick="analyticsFunc(this)" title="Business Urdu News - Latest live Business World News updates today in Urdu by Geo News Urdu">کاروبار</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Health" data-page_type="Listing Page" href="https://urdu.geo.tv/category/health" onclick="analyticsFunc(this)" title="Health Urdu News - Latest live Health World News updates today in Urdu by Geo News Urdu">صحت</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Amazing" data-page_type="Listing Page" href="https://urdu.geo.tv/category/amazing" onclick="analyticsFunc(this)" title="Amazing Urdu News - Latest live Amazing World News updates today in Urdu by Geo News Urdu">دلچسپ و عجیب</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Blog" data-page_type="Listing Page" href="https://urdu.geo.tv/category/blog" onclick="analyticsFunc(this)" title="Urdu Blogs from Pakistan on Geo News Urdu">بلاگ</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="TV Shows" data-page_type="Listing Page" href="https://urdu.geo.tv/tv-shows"  ...
# <div class="logo-white"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/> </div>
# <div class="logo-blck"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/> </div>
# <div class="logo-green" style="display: none"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo-green.svg"/> </div>
# </a>, <a data-event="tvc_top_navigation" data-event_action="live_tv" data-page_type="Homepage" href="http://live.geo.tv/" onclick="analyticsFunc(this)" target="_blank">
# <div class="icon" style="display: block">
# <img src="https://urdu.geo.tv/assets/front/images/GEOURDU-TV-ICON.png"/>
# </div>
# </a>, <a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/></a>, <a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/urdu-logo.png?v=23987"/></a>, <a data-event="tvc_top_navigation" data-event_action="GeoUrduLogo_click" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)"><img src="https://urdu.geo.tv/assets/front/images/logo_.svg?v=239"/></a>, <a href="#" id="close-nav">X</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="live_tv" data-page_type="Homepage" href="https://live.geo.tv/" onclick="analyticsFunc(this)" target="_blank" title="Live TV"><img src="https://urdu.geo.tv/assets/front/images/GEOURDU-TV-ICON.png"/></a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Home" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Latest" data-page_type="Listing Page" href="https://urdu.geo.tv/latest-news" onclick="analyticsFunc(this)" title="Latest Urdu News Live today &amp; online breaking news updates in Urdu from Pakistan, Sports, Entertainment - Geo News Urdu">تازہ ترین</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="KPK Election" data-page_type="Listing Page" href="https://urdu.geo.tv/election/kp-localbodies2021/" onclick="analyticsFunc(this)" style="color: red;" title="Pakistan Urdu News - Latest live KPK Election News updates today in Urdu by Geo News Urdu">کے پی بلدیاتی الیکشن</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://urdu.geo.tv/category/pakistan" onclick="analyticsFunc(this)" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">پاکستان</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="World" data-page_type="Listing Page" href="https://urdu.geo.tv/category/world" onclick="analyticsFunc(this)" title="World Urdu News - Latest live breaking World News updates today in Urdu by Geo News Urdu">دنیا</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Sports" data-page_type="Listing Page" href="https://urdu.geo.tv/category/sports" onclick="analyticsFunc(this)" title="Sports Urdu News - Latest live Sports World News updates today in Urdu by Geo News Urdu">کھیل</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Entertainment" data-page_type="Listing Page" href="https://urdu.geo.tv/category/entertainment" onclick="analyticsFunc(this)" title="Entertainment Urdu News - Latest live Entertainment World News updates today in Urdu by Geo News Urdu">انٹرٹینمنٹ</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Business" data-page_type="Listing Page" href="https://urdu.geo.tv/category/business" onclick="analyticsFunc(this)" title="Business Urdu News - Latest live Business World News updates today in Urdu by Geo News Urdu">کاروبار</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="TV Shows" data-page_type="Listing Page" href="https://urdu.geo.tv/tv-shows" onclick="analyticsFunc(this)" title="TV Shows">شوز</a>, <a class="open-section" data-event="tvc_top_navigation" data-event_action="Videos" data-page_type="Listing Page" href="https://urdu.geo.tv/videos" onclick="analyticsFunc(this)" title="Urdu Videos News Packages - Latest live video updates of breaking news today in Urdu by Geo Ne ...
# <img src="https://urdu.geo.tv/sites/top-news-stories-of-2021-in-pakistan/img/GEO-banner-urdu.png" style="max-width:100%;"/>
# </a>, <a class="open-section" data-article_name="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" data-event_action="featured" data-position="1" data-vr-contentbox="Home Featured 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273610-" href="https://urdu.geo.tv/latest/273610-" onclick="getClick(this)" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/l_273610_022026_updates.jpg" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان"/>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان&amp;url=https://urdu.geo.tv/latest/273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273610-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان" data-event_action="featured" data-position="1" data-vr-contentbox="Home Featured 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273610-" href="https://urdu.geo.tv/latest/273610-" onclick="getClick(this)" title="نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان">
# <h1 data-vr-headline="">نواز شریف کی وطن واپسی کا معاملہ، وفاق کا شہباز شریف کیخلاف کارروائی کا اعلان</h1>
# </a>, <a class="open-section" data-article_name="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" data-event_action="featured" data-position="2" data-vr-contentbox="Home Featured 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273619-" href="https://urdu.geo.tv/latest/273619-" onclick="getClick(this)" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب">
# <h2 data-vr-headline="">نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب</h2>
# </a>, <a class="open-section" data-article_name="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" data-event_action="featured" data-position="2" data-vr-contentbox="Home Featured 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273619-" href="https://urdu.geo.tv/latest/273619-" onclick="getClick(this)" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273619_054008_updates.jpg" title="نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب"/>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273619-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=نواز شریف علاج مکمل ہونے اور ڈاکٹرزکی اجازت پر ہی واپس آئیں گے، مریم اورنگزیب&amp;url=https://urdu.geo.tv/latest/273619-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273619-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘" data-event_action="featured" data-position="3" data-vr-contentbox="Home Featured 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273637-" href="https://urdu.geo.tv/latest/273637-" onclick="getClick(this)" title="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘">
# <h2 data-vr-headline="">’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘</h2>
# </a>, <a class="open-section" data-article_name="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘" data-event_action="featured" data-position="3" data-vr-contentbox="Home Featured 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273637-" href="https://urdu.geo.tv/latest/273637-" onclick="getClick(this)" title="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273637_091238_updates.jpg" title="’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘"/>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273637-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=’2018 کے انتخابی عمل میں مداخلت کی گئی، بلدیاتی انتخابات میں ’وہ‘ غیر جانبدار نظر آئے‘&amp;url=https://urdu.geo.tv/latest/273637-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273637-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="کرپشن مسلم دنیا کا سب سے بڑا مسئلہ ہے، وزیراعظم کا اسکالرز کیساتھ مکالمہ" data-event_action="featured" data-position="4" data-vr-contentbox="Home Featured 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273625-" href="https://urdu.geo.tv/latest/273625-" onclick="getClick(this)" title="کرپشن مسلم دنیا کا سب سے بڑا مسئلہ ہے، وزیراعظم کا اسکالرز کیساتھ مکالمہ">
# <h2 data-vr-headline="">کرپشن مسلم دنیا کا سب سے بڑا مسئلہ ہے، وزیراعظم کا اسکالرز کیساتھ مکالمہ
نخواہ کم ہے، کئی دفعہ صدر سے درخواست کی کہ تنخواہ بڑھا دیں: گورنرپختونخوا" data-event_action="featured" data-position="9" data-vr-contentbox="Home Featured 9" data-vr-contentbox-url="https://urdu.geo.tv/latest/273582-" href="https://urdu.geo.tv/latest/273582-" onclick="getClick(this)" title="تنخواہ کم ہے، کئی دفعہ صدر سے درخواست کی کہ تنخواہ بڑھا دیں: گورنرپختونخوا">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="تنخواہ کم ہے، کئی دفعہ صدر سے درخواست کی کہ تنخواہ بڑھا دیں: گورنرپختونخوا" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-01/s_273582_120229_updates.jpg" title="تنخواہ کم ہے، کئی دفعہ صدر سے درخواست کی کہ تنخواہ بڑھا دیں: گورنرپختونخوا"/>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273582-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=تنخواہ کم ہے، کئی دفعہ صدر سے درخواست کی کہ تنخواہ بڑھا دیں: گورنرپختونخوا&amp;url=https://urdu.geo.tv/latest/273582-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273582-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار" data-event_action="featured" data-position="10" data-vr-contentbox="Home Featured 10" data-vr-contentbox-url="https://urdu.geo.tv/latest/273621-" href="https://urdu.geo.tv/latest/273621-" onclick="getClick(this)" title="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار">
# <h2 data-vr-headline="">گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار</h2>
# </a>, <a class="open-section" data-article_name="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار" data-event_action="featured" data-position="10" data-vr-contentbox="Home Featured 10" data-vr-contentbox-url="https://urdu.geo.tv/latest/273621-" href="https://urdu.geo.tv/latest/273621-" onclick="getClick(this)" title="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273621_061750_updates.jpg" title="گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار"/>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273621-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=گریٹر اقبال پارک میں برقع پہن کر خواتین کو ہراساں کرنے والے 2 نوجوان گرفتار&amp;url=https://urdu.geo.tv/latest/273621-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273621-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی" data-event_action="Top Story" data-position="1" data-vr-contentbox="Home Top Stories 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273634-" href="https://urdu.geo.tv/latest/273634-" onclick="getClick(this)" title="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی">
# <div class="m_pic">
# <picture>
# <source alt="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273634_084423_updates.jpg" title="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی"/>
# <img alt="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273634_084423_updates.jpg" title="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی&amp;url=https://urdu.geo.tv/latest/273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی" data-event_action="Top Story" data-position="1" data-vr-contentbox="Home Top Stories 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273634-" href="https://urdu.geo.tv/latest/273634-" onclick="getClick(this)" title="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی"><h2 data-vr-headline="">اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی</h2></a>
# </div>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی&amp;url=https://urdu.geo.tv/latest/273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273634-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی" data-event_action="Top Story" data-position="1" data-vr-contentbox="Home Top Stories 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273634-" href="https://urdu.geo.tv/latest/273634-" onclick="getClick(this)" title="اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی"><h2 data-vr-headline="">اے آر رحمان کی بیٹی کی منگنی، خدیجہ نے منگیتر کی تصویر شیئر کردی</h2></a>, <a class="open-section" data-article_name="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" data-event_action="Top Story" data-position="2" data-vr-contentbox="Home Top Stories 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273617-" href="https://urdu.geo.tv/latest/273617-" onclick="getClick(this)" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے">
# <div class="m_pic">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span>
# <picture>
# <source alt="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273617_050704_updates.jpg" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے"/>
# <img alt="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273617_050704_updates.jpg" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=لیونل میسی بھی کورونا وائرس کا شکار ہوگئے&amp;url=https://urdu.geo.tv/latest/273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" data-event_action="Top Story" data-position="2" data-vr-contentbox="Home Top Stories 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273617-" href="https://urdu.geo.tv/latest/273617-" onclick="getClick(this)" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے"><h2 data-vr-headline="">لیونل میسی بھی کورونا وائرس کا شکار ہوگئے</h2></a>
# </div>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=لیونل میسی بھی کورونا وائرس کا شکار ہوگئے&amp;url=https://urdu.geo.tv/latest/273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273617-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" data-event_action="Top Story" data-position="2" data-vr-contentbox="Home Top Stories 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273617-" href="https://urdu.geo.tv/latest/273617-" onclick="getClick(this)" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے"><h2 data-vr-headline="">لیونل میسی بھی کورونا وائرس کا شکار ہوگئے</h2></a>, <a class="open-section" data-article_name="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی" data-event_action="Top Story" data-position="3" data-vr-contentbox="Home Top Stories 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273622-" href="https://urdu.geo.tv/latest/273622-" onclick="getClick(this)" title="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی">
# <div class="m_pic">
# <picture>
# <source alt="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273622_064057_updates.jpg" title="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی"/>
# <img alt="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273622_064057_updates.jpg" title="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی&amp;url=https://urdu.geo.tv/latest/273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی" data-event_action="Top Story" data-position="3" data-vr-contentbox="Home Top Stories 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273622-" href="https://urdu.geo.tv/latest/273622-" onclick="getClick(this)" title="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی"><h2 data-vr-headline="">بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی</h2></a>
# </div>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی&amp;url=https://urdu.geo.tv/latest/273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273622-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی" data-event_action="Top Story" data-position="3" data-vr-contentbox="Home Top Stories 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273622-" href="https://urdu.geo.tv/latest/273622-" onclick="getClick(this)" title="بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی"><h2 data-vr-headline="">بلاول کا زخمی لیگی رکن اسمبلی بلال یاسین کو ٹیلیفون، خیریت دریافت کی</h2></a>, <a class="open-section" data-article_name="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات" data-event_action="Top Story" data-position="4" data-vr-contentbox="Home Top Stories 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273629-" href="https://urdu.geo.tv/latest/273629-" onclick="getClick(this)" title="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات">
# <div class="m_pic">
# <picture>
# <source alt="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273629_081917_updates.jpg" title="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات"/>
# <img alt="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273629_081917_updates.jpg" title="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات&amp;url=https://urdu.geo.tv/latest/273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات" data-event_action="Top Story" data-position="4" data-vr-contentbox="Home Top Stories 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273629-" href="https://urdu.geo.tv/latest/273629-" onclick="getClick(this)" title="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات"><h2 data-vr-headline="">شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات</h2></a>
# </div>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات&amp;url=https://urdu.geo.tv/latest/273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273629-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات" data-event_action="Top Story" data-position="4" data-vr-contentbox="Home Top Stories 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273629-" href="https://urdu.geo.tv/latest/273629-" onclick="getClick(this)" title="شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات"><h2 data-vr-headline="">شادی میں غیر ملکی کرنسی، موبائل فونز اور قیمتی تحائف کی برسات</h2></a>, <a class="open-section" data-article_name="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" data-event_action="Top Story" data-position="5" data-vr-contentbox="Home Top Stories 5" data-vr-contentbox-url="https://urdu.geo.tv/latest/273616-" href="https://urdu.geo.tv/latest/273616-" onclick="getClick(this)" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں">
# <div class="m_pic">
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span>
# <picture>
# <source alt="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273616_035919_updates.jpg" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں"/>
# <img alt="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273616_035919_updates.jpg" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# <a href="https://twitter.com/share?text=حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں&amp;url=https://urdu.geo.tv/latest/273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>
# <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>
# </div>
# </div>
# <div class="heading">
# <a class="open-section" data-article_name="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" data-event_action="Top Story" data-position="5" data-vr-contentbox="Home Top Stories 5" data-vr-contentbox-url="https://urdu.geo.tv/latest/273616-" href="https://urdu.geo.tv/latest/273616-" onclick="getClick(this)" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں"><h2 data-vr-headline="">حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں</h2></a>
# </div>
# </a>, <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>, <a href="https://twitter.com/share?text=حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں&amp;url=https://urdu.geo.tv/latest/273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/twitter_hover.png"/></a>, <a href="https://api.whatsapp.com/send?text=https://urdu.geo.tv/latest/273616-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/whatsapp_hover.png"/></a>, <a class="open-section" data-article_name="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" data-event_action="Top Story" data-position="5" data-vr-contentbox="Home Top Stories 5" data-vr-contentbox-url="https://urdu.geo.tv/latest/273616-" href="https://urdu.geo.tv/latest/273616-" onclick="getClick(this)" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں"><h2 data-vr-headline="">حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں</h2></a>, <a class="open-section" data-article_name="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج" data-event_action="Top Story" data-position="6" data-vr-contentbox="Home Top Stories 6" data-vr-contentbox-url="https://urdu.geo.tv/latest/273602-" href="https://urdu.geo.tv/latest/273602-" onclick="getClick(this)" title="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج">
# <div class="m_pic">
# <picture>
# <source alt="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج" media="(max-width: 480px)" srcset="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/s_273602_121245_updates.jpg" title="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج"/>
# <img alt="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273602_121245_updates.jpg" title="سارہ کیساتھ بائیک پر سواری، وکی کوشل کیخلاف پولیس میں شکایت درج"/>
# </picture>
# <div class="hover_share">
# <a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Furdu.geo.tv%2Flatest%2F273602-" target="_blank"><img alt="facebook" class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/facebook_hover.png"/></a>
# ...
# <span class="video-icon"><img class="lazyload" data-src="https://urdu.geo.tv/assets/front/images/video-icon.svg"/></span> <img alt="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273616_035919_updates.jpg" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں"/>
# </a>, <a class="open-section" data-article_name="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں" data-event_action="Sports" data-position="1" data-vr-contentbox="Home Sports 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273616-" href="https://urdu.geo.tv/latest/273616-" onclick="getClick(this)" title="حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں">حسنین کا بگ بیش میں پہلا ہی اوور میڈن، 3 وکٹیں بھی لیں</a>, <a class="open-section" data-article_name="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے" data-event_action="Sports" data-position="2" data-vr-contentbox="Home Sports 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273617-" href="https://urdu.geo.tv/latest/273617-" onclick="getClick(this)" title="لیونل میسی بھی کورونا وائرس کا شکار ہوگئے">لیونل میسی بھی کورونا وائرس کا شکار ہوگئے</a>, <a class="open-section" data-article_name="ایشز سیریز، انگلش کیمپ میں کورونا کی وجہ سے کھلبلی مچ گئی" data-event_action="Sports" data-position="3" data-vr-contentbox="Home Sports 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273606-" href="https://urdu.geo.tv/latest/273606-" onclick="getClick(this)" title="ایشز سیریز، انگلش کیمپ میں کورونا کی وجہ سے کھلبلی مچ گئی">ایشز سیریز، انگلش کیمپ میں کورونا کی وجہ سے کھلبلی مچ گئی</a>, <a class="open-section" data-article_name="اعصام الحق کی والدین کے ہمراہ ڈانس کی ویڈیو" data-event_action="Sports" data-position="4" data-vr-contentbox="Home Sports 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273547-" href="https://urdu.geo.tv/latest/273547-" onclick="getClick(this)" title="اعصام الحق کی والدین کے ہمراہ ڈانس کی ویڈیو">اعصام الحق کی والدین کے ہمراہ ڈانس کی ویڈیو</a>, <a href="https://urdu.geo.tv/category/business">کاروبار</a>, <a class="open-section cat-open" data-article_name="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت" data-event_action="Business" data-position="1" data-vr-contentbox="Home Business 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273615-" href="https://urdu.geo.tv/latest/273615-" onclick="getClick(this)" style="display: block;" title="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت">
# <img alt="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت" class="lazyload" data-src="https://urdu.geo.tv//assets/uploads/updates/2022-01-02/t_273615_032813_updates.jpg" title="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت"/>
# </a>, <a class="open-section" data-article_name="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت" data-event_action="Business" data-position="1" data-vr-contentbox="Home Business 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/273615-" href="https://urdu.geo.tv/latest/273615-" onclick="getClick(this)" title="رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت">رواں مالی سال کے پہلے 6 ماہ برآمدات میں 25 فیصد اضافہ ہوا: مشیر تجارت</a>, <a class="open-section" data-article_name="اوگرا کی پیٹرول 3روپے 2 پیسے مہنگا کرنےکی تجویز، حکومت نے 4 روپے بڑھا دیے" data-event_action="Business" data-position="2" data-vr-contentbox="Home Business 2" data-vr-contentbox-url="https://urdu.geo.tv/latest/273623-" href="https://urdu.geo.tv/latest/273623-" onclick="getClick(this)" title="اوگرا کی پیٹرول 3روپے 2 پیسے مہنگا کرنےکی تجویز، حکومت نے 4 روپے بڑھا دیے">اوگرا کی پیٹرول 3روپے 2 پیسے مہنگا کرنےکی تجویز، حکومت نے 4 روپے بڑھا دیے</a>, <a class="open-section" data-article_name="عوام  پر 17 ارب 85 کروڑ  روپے کا بوجھ ڈالنے کی ایک اور درخواست نیپراکو  موصول" data-event_action="Business" data-position="3" data-vr-contentbox="Home Business 3" data-vr-contentbox-url="https://urdu.geo.tv/latest/273577-" href="https://urdu.geo.tv/latest/273577-" onclick="getClick(this)" title="عوام  پر 17 ارب 85 کروڑ  روپے کا بوجھ ڈالنے کی ایک اور درخواست نیپراکو  موصول">عوام پر 17 ارب 85 کروڑ روپے کا بوجھ ڈالنے کی ایک اور درخواست نیپراکو موصول</a>, <a class="open-section" data-article_name="منی بجٹ کے بعد موبائل فونز کتنے مہنگے ہوجائیں گے؟ " data-event_action="Business" data-position="4" data-vr-contentbox="Home Business 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273573-" href="https://urdu.geo.tv/latest/273573-" onclick="getClick(this)" title="منی بجٹ کے بعد موبائل فونز کتنے مہنگے ہوجائیں گے؟ ">منی بجٹ کے بعد موبائل فونز کتنے مہنگے ہوجائیں گے؟ </a>, <a href="https://urdu.geo.tv/category/science-technology">سائنس و ٹیکنالوجی</a>, <a class="open-section cat-open" data-article_name="بلیک بیری استعمال کرنے والوں کیلئے بری خبر، کمپنی نے اہم اعلان کردیا" data-event_action="Health" data-position="1" data-vr-contentbox="Home Health 1" data-vr-contentbox-url="https://urdu.geo.tv/latest/
latest/273588-" onclick="getClick(this)" title="اب بتائیں!">اب بتائیں!</a>, <a class="open-section" data-article_name="ملکی معیشت اور نواز شریف!" data-event_action="Blog" data-position="4" data-vr-contentbox="Home Blog 4" data-vr-contentbox-url="https://urdu.geo.tv/latest/273587-" href="https://urdu.geo.tv/latest/273587-" onclick="getClick(this)" title="ملکی معیشت اور نواز شریف!">ملکی معیشت اور نواز شریف!</a>, <a data-event="tvc_bottom_navigation" data-event_action="Home" data-page_type="Homepage" href="https://urdu.geo.tv/" onclick="analyticsFunc(this)" title="Urdu News - Latest live Breaking News updates today in Urdu, Livestream &amp; online Videos - Geo News Urdu">صفحہ اول</a>, <a data-event="tvc_bottom_navigation" data-event_action="Latest" data-page_type="Listing Page" href="https://urdu.geo.tv/latest-news" onclick="analyticsFunc(this)" title="Latest Urdu News Live today &amp; online breaking news updates in Urdu from Pakistan, Sports, Entertainment - Geo News Urdu">تازہ ترین</a>, <a data-event="tvc_bottom_navigation" data-event_action="Pakistan" data-page_type="Listing Page" href="https://urdu.geo.tv/category/pakistan" onclick="analyticsFunc(this)" title="Pakistan Urdu News - Latest live breaking Pakistani News updates today in Urdu by Geo News Urdu">پاکستان</a>, <a data-event="tvc_bottom_navigation" data-event_action="World" data-page_type="Listing Page" href="https://urdu.geo.tv/category/world" onclick="analyticsFunc(this)" title="World Urdu News - Latest live breaking World News updates today in Urdu by Geo News Urdu">دنیا</a>, <a data-event="tvc_bottom_navigation" data-event_action="SPORTS" data-page_type="Listing Page" href="https://urdu.geo.tv/category/sports" onclick="analyticsFunc(this)" title="Sports Urdu News - Latest live Sports World News updates today in Urdu by Geo News Urdu">کھیل</a>, <a data-event="tvc_bottom_navigation" data-event_action="ENTERTAINMENT" data-page_type="Listing Page" href="https://urdu.geo.tv/category/entertainment" onclick="analyticsFunc(this)" title="Entertainment Urdu News - Latest live Entertainment World News updates today in Urdu by Geo News Urdu">انٹرٹینمنٹ</a>, <a data-event="tvc_bottom_navigation" data-event_action="BUSINESS" data-page_type="Listing Page" href="https://urdu.geo.tv/category/business" onclick="analyticsFunc(this)" title="Business Urdu News - Latest live Business World News updates today in Urdu by Geo News Urdu">کاروبار</a>, <a data-event="tvc_bottom_navigation" data-event_action="HEALTH" data-page_type="Listing Page" href="https://urdu.geo.tv/category/health" onclick="analyticsFunc(this)" title="Health Urdu News - Latest live Health World News updates today in Urdu by Geo News Urdu">صحت</a>, <a data-event="tvc_bottom_navigation" data-event_action="AMAZING" data-page_type="Listing Page" href="https://urdu.geo.tv/category/amazing" onclick="analyticsFunc(this)" title="Amazing Urdu News - Latest live Amazing World News updates today in Urdu by Geo News Urdu">دلچسپ و عجیب</a>, <a data-event="tvc_bottom_navigation" data-event_action="Blog" data-page_type="Listing Page" href="https://urdu.ge ...

# %%
all_links = set()

# %%
for link in anchors:
    if(link.get('href') != '#'):
        linkText = link.get('href')
        all_links.add(linkText)
        print(linkText)
# Out:
# https://urdu.geo.tv/
# https://urdu.geo.tv/
# https://urdu.geo.tv/election/constituency
